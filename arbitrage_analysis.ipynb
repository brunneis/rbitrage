# %% [markdown]
# # 04/12/2017
# # Arbitrage between Kraken and GDAX
# Profit results considering a swap operation of 1 coin (LTC, ETH or BTC)
#
# <img style="float: left;" src="https://paxforex.com/sites/default/files/images/what_is_forex_arbitrage_trading.jpg">

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
import matplotlib.pyplot as plt
# %matplotlib inline

mpl.rcParams['xtick.labelsize'] = 16
mpl.rcParams['ytick.labelsize'] = 16

def fixy(ax):
    ax.xaxis.set_major_locator(mdates.MinuteLocator(interval=60))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
    return ax
    
def fixx(ax):
    ax.yaxis.set_major_locator(mticker.MaxNLocator())
    return ax

# %%
date='04122017'

# %% [markdown]
# ## LTC arbitrage

# %%
df_ltc = pd.read_csv("https://egr.brunneis.com/0142c2a2f13c78e9b34ad89c5166c24d7308886a4868ee72d45d5f0d7d8f4d8a/ltceur/ltceur_" + date + ".csv", parse_dates=True)
df_ltc.datetime= pd.to_datetime(df_ltc['datetime'], format='%Y-%m-%d %H:%M:%S.%f')

# Custom number of available coins (1 by default)
# available_ltc = 5
# df_ltc.profit = df_ltc.profit * available_ltc
# df_ltc.quantity = df_ltc.quantity * available_ltc

# %% [markdown]
# #### Profit vs. LTC price on GDAX and Kraken

# %%
fixy(fixx(df_ltc.plot(kind='line', x='datetime', y=['profit', 'gdax', 'kraken'], figsize=(20,10), grid=True)))

# %%
fixy(fixx(df_ltc.plot(kind='line', x='datetime', y='profit', figsize=(20,10), grid=True)))

# %% [markdown]
# #### LTC price on GDAX vs. LTC price on Kraken

# %%
fixy(fixx(df_ltc.plot(kind='line', x='datetime', y=['gdax', 'kraken'], figsize=(20,10), grid=True)))

# %% [markdown]
# #### Distribution of profit for LTC

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,10))
fixx(df_ltc.plot(kind='density', y='profit', ax=axes[0], grid=True))
fixx(df_ltc.plot(kind='box', y='profit', ax=axes[1], grid=True))

# %% [markdown]
# ## ETH arbitrage

# %%
df_eth = pd.read_csv("https://egr.brunneis.com/0142c2a2f13c78e9b34ad89c5166c24d7308886a4868ee72d45d5f0d7d8f4d8a/etheur/etheur_" + date + ".csv", parse_dates=True)
df_eth.datetime= pd.to_datetime(df_eth['datetime'], format='%Y-%m-%d %H:%M:%S.%f')

# Custom number of available coins (1 by default)
# available_eth = 5
# df_eth.profit = df_eth.profit * available_eth
# df_eth.quantity = df_eth.quantity * available_eth

# %% [markdown]
# #### Profit vs. ETH price on GDAX and Kraken

# %%
fixy(fixx(df_eth.plot(kind='line', x='datetime', y=['profit', 'gdax', 'kraken'], figsize=(20,10), grid=True)))

# %%
fixy(fixx(df_eth.plot(kind='line', x='datetime', y='profit', figsize=(20,10), grid=True)))

# %% [markdown]
# #### ETH price on GDAX vs. ETH price on Kraken

# %%
fixy(fixx(df_eth.plot(kind='line', x='datetime', y=['gdax', 'kraken'], figsize=(20,10), grid=True)))

# %% [markdown]
# #### Distribution of profit for ETH

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,10))
fixx(df_eth.plot(kind='density', y='profit', ax=axes[0], grid=True))
fixx(df_eth.plot(kind='box', y='profit', ax=axes[1], grid=True))

# %% [markdown]
# ## BTC arbitrage

# %%
df_btc = pd.read_csv("https://egr.brunneis.com/0142c2a2f13c78e9b34ad89c5166c24d7308886a4868ee72d45d5f0d7d8f4d8a/btceur/btceur_" + date + ".csv", parse_dates=True)
df_btc.datetime= pd.to_datetime(df_btc['datetime'], format='%Y-%m-%d %H:%M:%S.%f')

# Custom number of available coins (1 by default)
# available_btc = 5
# df_btc.profit = df_btc.profit * available_btc
# df_btc.quantity = df_btc.quantity * available_btc

# %% [markdown]
# #### Profit vs. BTC price on GDAX and Kraken

# %%
fixy(fixx(df_btc.plot(kind='line', x='datetime', y=['profit', 'gdax', 'kraken'], figsize=(20,10), grid=True)))

# %% [markdown]
# #### BTC price on GDAX vs. BTC price on Kraken

# %%
fixy(fixx(df_btc.plot(kind='line', x='datetime', y=['gdax', 'kraken'], figsize=(20,10), grid=True)))

# %%
fixy(fixx(df_btc.plot(kind='line', x='datetime', y='profit', figsize=(20,10), grid=True)))

# %% [markdown]
# #### Distribution of profit for BTC

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,10))
fixx(df_btc.plot(kind='density', y='profit', ax=axes[0], grid=True))
fixx(df_btc.plot(kind='box', y='profit', ax=axes[1], grid=True))
